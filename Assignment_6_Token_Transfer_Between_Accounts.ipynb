# %% [markdown]
# # 📘 Assignment 6 - Write and Execute a Solidity Smart Contract to Transfer Tokens Between Accounts
#
# ## 🎯 Objective
# To design and implement a token transfer system using a smart contract on the Ethereum network using Solidity, and execute transactions between accounts.
#
# ## 🧠 Concepts Used
# 1. Smart Contract
#    A decentralized program that runs on blockchain.
#    Handles token logic automatically.
# 2. Token System
#    Digital asset stored on blockchain.
#    Each account has a balance.
# 3. Mapping (Solidity)
#    Data structure used to store balances.
#    Example: mapping(address => uint) public balances;
# 4. Transfer Function
#    Moves tokens from one account to another.
#    Includes validation checks.
# 5. require() Function
#    Used for validation.
#    Stops execution if condition fails.
#
# ## ⚙️ Flow of Process
# Deploy Token Smart Contract
#         ↓
# Initialize Total Supply
#         ↓
# Assign Tokens to Owner
#         ↓
# Call Transfer Function
#         ↓
# Check Sender Balance
#         ↓
# Update Sender & Receiver Balances
#         ↓
# Transaction Stored on Blockchain

# %% [markdown]
# ## 🔹 Step 1: Install Libraries

# %%
# !pip install web3 py-solc-x
# Out:
# Collecting web3
#   Downloading web3-7.14.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting py-solc-x
#   Downloading py_solc_x-2.0.5-py3-none-any.whl.metadata (5.9 kB)
# Collecting eth-abi>=5.0.1 (from web3)
#   Downloading eth_abi-5.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting eth-account>=0.13.6 (from web3)
#   Downloading eth_account-0.13.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting eth-hash>=0.5.1 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Downloading eth_hash-0.8.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting eth-typing>=5.0.0 (from web3)
#   Downloading eth_typing-6.0.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting eth-utils>=5.0.0 (from web3)
#   Downloading eth_utils-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting hexbytes>=1.2.0 (from web3)
#   Downloading hexbytes-1.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiohttp>=3.7.4.post0 (from web3)
#   Downloading aiohttp-3.13.5-cp310-cp310-win_amd64.whl.metadata (8.4 kB)
# Collecting pydantic>=2.4.0 (from web3)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting pywin32>=223 (from web3)
#   Using cached pywin32-311-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Collecting requests>=2.23.0 (from web3)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: typing-extensions>=4.0.1 in .\.venv\lib\site-packages (from web3) (4.15.0)
# Collecting types-requests>=2.0.0 (from web3)
#   Downloading types_requests-2.33.0.20260327-py3-none-any.whl.metadata (2.0 kB)
# Collecting websockets<16.0.0,>=10.0.0 (from web3)
#   Using cached websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Collecting pyunormalize>=15.0.0 (from web3)
#   Downloading pyunormalize-17.0.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging>=23.1 in .\.venv\lib\site-packages (from py-solc-x) (26.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.23.0->web3)
#   Using cached charset_normalizer-3.4.6-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->web3)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.23.0->web3)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests>=2.23.0->web3)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.7.4.post0->web3)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp>=3.7.4.post0->web3)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp>=3.7.4.post0->web3)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.7.4.post0->web3)
#   Downloading attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.7.4.post0->web3)
#   Using cached frozenlist-1.8.0-cp310-cp310-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7.4.post0->web3)
#   Using cached multidict-6.7.1-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.7.4.post0->web3)
#   Using cached propcache-0.4.1-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.7.4.post0->web3)
#   Downloading yarl-1.23.0-cp310-cp310-win_amd64.whl.metadata (82 kB)
# Collecting parsimonious<0.11.0,>=0.10.0 (from eth-abi>=5.0.1->web3)
#   Downloading parsimonious-0.10.0-py3-none-any.whl.metadata (25 kB)
# Collecting regex>=2022.3.15 (from parsimonious<0.11.0,>=0.10.0->eth-abi>=5.0.1->web3)
#   Downloading regex-2026.3.32-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting bitarray>=2.4.0 (from eth-account>=0.13.6->web3)
#   Downloading bitarray-3.8.0-cp310-cp310-win_amd64.whl.metadata (35 kB)
# Collecting eth-abi>=5.0.1 (from web3)
#   Downloading eth_abi-6.0.0b1-py3-none-any.whl.metadata (3.8 kB)
# Collecting eth-keyfile<0.9.0,>=0.7.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_keyfile-0.8.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting eth-keys>=0.4.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_keys-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting eth-rlp>=2.1.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_rlp-2.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting rlp>=1.0.0 (from eth-account>=0.13.6->web3)
#   Downloading rlp-4.1.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting ckzg>=2.0.0 (from eth-account>=0.13.6->web3)
#   Downloading ckzg-2.1.7-cp310-cp310-win_amd64.whl.metadata (930 bytes)
# Collecting pycryptodome<4,>=3.6.6 (from eth-keyfile<0.9.0,>=0.7.0->eth-account>=0.13.6->web3)
#   Downloading pycryptodome-3.23.0-cp37-abi3-win_amd64.whl.metadata (3.5 kB)
# Collecting cytoolz>=0.10.1 (from eth-utils>=5.0.0->web3)
#   Downloading cytoolz-1.1.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.4.0->web3)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.4.0->web3)
#   Using cached pydantic_core-2.41.5-cp310-cp310-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.4.0->web3)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting toolz>=0.8.0 (from cytoolz>=0.10.1->eth-utils>=5.0.0->web3)
#   Downloading toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Downloading web3-7.14.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ---------------------- ----------------- 0.8/1.4 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.4 MB/s  0:00:00
# Using cached websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
# Downloading py_solc_x-2.0.5-py3-none-any.whl (18 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.6-cp310-cp310-win_amd64.whl (154 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading aiohttp-3.13.5-cp310-cp310-win_amd64.whl (462 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Using cached multidict-6.7.1-cp310-cp310-win_amd64.whl (46 kB)
# Downloading yarl-1.23.0-cp310-cp310-win_amd64.whl (87 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading eth_abi-5.2.0-py3-none-any.whl (28 kB)
# Downloading parsimonious-0.10.0-py3-none-any.whl (48 kB)
# Downloading eth_account-0.13.7-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.5 kB ? eta -:--:--
#    ----------------------------------- ---- 524.3/587.5 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 587.5/587.5 kB 2.6 MB/s  0:00:00
# Downloading eth_keyfile-0.8.1-py3-none-any.whl (7.5 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 4.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 2.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.8 MB/s  0:00:00
# Downloading bitarray-3.8.0-cp310-cp310-win_amd64.whl (149 kB)
# Downloading ckzg-2.1.7-cp310-cp310-win_amd64.whl (99 kB)
# Downloading eth_hash-0.8.0-py3-none-any.whl (8.0 kB)
# Downloading eth_keys-0.7.0-py3-none-any.whl (20 kB)
# Downloading eth_rlp-2.2.0-py3-none-any.whl (4.4 kB)
# Downloading eth_typing-6.0.0-py3-none-any.whl (19 kB)
# Downloading eth_utils-6.0.0-py3-none-any.whl (102 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp310-cp310-win_amd64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cytoolz-1.1.0-cp310-cp310-win_amd64.whl (944 kB)
#    ---------------------------------------- 0.0/944.8 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/944.8 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 944.8/944.8 kB 3.4 MB/s  0:00:00
# Using cached frozenlist-1.8.0-cp310-cp310-win_amd64.whl (43 kB)
# Downloading hexbytes-1.3.1-py3-none-any.whl (5.1 kB)
# Using cached propcache-0.4.1-cp310-cp310-win_amd64.whl (41 kB)
# Downloading pyunormalize-17.0.0-py3-none-any.whl (51 kB)
# Using cached pywin32-311-cp310-cp310-win_amd64.whl (9.6 MB)
# Downloading regex-2026.3.32-cp310-cp310-win_amd64.whl (278 kB)
# Downloading rlp-4.1.0-py3-none-any.whl (19 kB)
# Downloading toolz-1.1.0-py3-none-any.whl (58 kB)
# Downloading types_requests-2.33.0.20260327-py3-none-any.whl (20 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: pywin32, ckzg, bitarray, websockets, urllib3, typing-inspection, toolz, regex, pyunormalize, pydantic-core, pycryptodome, propcache, multidict, idna, hexbytes, frozenlist, eth-typing, eth-hash, charset_normalizer, certifi, attrs, async-timeout, annotated-types, aiohappyeyeballs, yarl, types-requests, requests, pydantic, parsimonious, cytoolz, aiosignal, py-solc-x, eth-utils, aiohttp, rlp, eth-keys, eth-abi, eth-rlp, eth-keyfile, eth-account, web3
#
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    ----------------------------------------  0/41 [pywin32]
#    - --------------------------------------  2/41 [bitarray]
#    -- -------------------------------------  3/41 [websockets]
#    -- -------------------------------------  3/41 [websockets]
#    -- -------------------------------------  3/41 [websockets]
#    -- -------------------------------------  3/41 [websockets]
#    -- -------------------------------------  3/41 [websockets]
#    -- -------------------------------------  3/41 [websockets]
#    -- -------------------------------------  3/41 [websockets]
#    -- -------------------------------------  3/41 [websockets]
#    -- -------------------------------------  3/41 [websockets]
#    --- ------------------------------------  4/41 [urllib3]
#    --- ------------------------------------  4/41 [urllib3]
#    --- ------------------------------------  4/41 [urllib3]
#    --- ------------------------------------  4/41 [urllib3]
#    --- ------------------------------------  4/41 [urllib3]
#    --- ------------------------------------  4/41 [urllib3]
#    --- ------------------------------------  4/41 [urllib3]
#    --- ------------------------------------  4/41 [urllib3]
#    ---- -----------------------------------  5/41 [typing-inspection]
#    ----- ----------------------------------  6/41 [toolz]
#    ----- ----------------------------------  6/41 [toolz]
#    ----- ----------------------------------  6/41 [toolz]
#    ----- ----------------------------------  6/41 [toolz]
#    ----- ----------------------------------  6/41 [toolz]
#    ------ ---------------------------------  7/41 [regex]
#    ------ ---------------------------------  7/41 [regex]
#    ------- --------------------------------  8/41 [pyunormalize]
#    -------- -------------------------------  9/41 [pydantic-core]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    --------- ------------------------------ 10/41 [pycryptodome]
#    ----------- ---------------------------- 12/41 [multidict]
#    ------------ --------------------------- 13/41 [idna]
#    ------------ --------------------------- 13/41 [idna]
#    ------------- -------------------------- 14/41 [hexbytes]
#    --------------- ------------------------ 16/41 [eth-typing]
#    ---------------- ----------------------- 17/41 [eth-hash]
#    ---------------- ----------------------- 17/41 [eth-hash]
#    ---------------- ----------------------- 17/41 [eth-hash]
#    ----------------- ---------------------- 18/41 [charset_normalizer]
#    ----------------- ---------------------- 18/41 [charset_normalizer]
#    ----------------- ---------------------- 18/41 [charset_normalizer]
#    ------------------ --------------------- 19/41 [certifi]
#    ------------------- -------------------- 20/41 [attrs]
#    ------------------- -------------------- 20/41 [attrs]
#    ------------------- -------------------- 20/41 [attrs]
#    ---------------------- ----------------- 23/41 [aiohappyeyeballs]
#    ----------------------- ---------------- 24/41 [yarl]
#    ----------------------- ---------------- 24/41 [yarl]
#    ------------------------- -------------- 26/41 [requests]
#    ------------------------- -------------- 26/41 [requests]
#    ------------------------- -------------- 26/41 [requests]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    -------------------------- ------------- 27/41 [pydantic]
#    --------------------------- ------------ 28/41 [parsimonious]
#    --------------------------- ------------ 28/41 [parsimonious]
#    ---------------------------- ----------- 29/41 [cytoolz]
#    ---------------------------- ----------- 29/41 [cytoolz]
#    ---------------------------- ----------- 29/41 [cytoolz]
#    ---------------------------- ----------- 29/41 [cytoolz]
#    ------------------------------ --------- 31/41 [py-solc-x]
#    ------------------------------- -------- 32/41 [eth-utils]
#    ------------------------------- -------- 32/41 [eth-utils]
#    ------------------------------- -------- 32/41 [eth-utils]
#    ------------------------------- -------- 32/41 [eth-utils]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    -------------------------------- ------- 33/41 [aiohttp]
#    --------------------------------- ------ 34/41 [rlp]
#    --------------------------------- ------ 34/41 [rlp]
#    ---------------------------------- ----- 35/41 [eth-keys]
#    ---------------------------------- ----- 35/41 [eth-keys]
#    ---------------------------------- ----- 35/41 [eth-keys]
#    ----------------------------------- ---- 36/41 [eth-abi]
#    ----------------------------------- ---- 36/41 [eth-abi]
#    ------------------------------------ --- 37/41 [eth-rlp]
#    -------------------------------------- - 39/41 [eth-account]
#    -------------------------------------- - 39/41 [eth-account]
#    -------------------------------------- - 39/41 [eth-account]
#    -------------------------------------- - 39/41 [eth-account]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------  40/41 [web3]
#    ---------------------------------------- 41/41 [web3]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 annotated-types-0.7.0 async-timeout-5.0.1 attrs-26.1.0 bitarray-3.8.0 certifi-2026.2.25 charset_normalizer-3.4.6 ckzg-2.1.7 cytoolz-1.1.0 eth-abi-5.2.0 eth-account-0.13.7 eth-hash-0.8.0 eth-keyfile-0.8.1 eth-keys-0.7.0 eth-rlp-2.2.0 eth-typing-6.0.0 eth-utils-6.0.0 frozenlist-1.8.0 hexbytes-1.3.1 idna-3.11 multidict-6.7.1 parsimonious-0.10.0 propcache-0.4.1 py-solc-x-2.0.5 pycryptodome-3.23.0 pydantic-2.12.5 pydantic-core-2.41.5 pyunormalize-17.0.0 pywin32-311 regex-2026.3.32 requests-2.33.1 rlp-4.1.0 toolz-1.1.0 types-requests-2.33.0.20260327 typing-inspection-0.4.2 urllib3-2.6.3 web3-7.14.1 websockets-15.0.1 yarl-1.23.0

# %% [markdown]
# ## 🔹 Step 2: Import Libraries

# %%
from web3 import Web3
from solcx import compile_source, install_solc

# %% [markdown]
# ## 🔹 Step 3: Install Solidity Compiler

# %%
install_solc('0.8.0')
# Out:
# <Version('0.8.0')>

# %% [markdown]
# ## 🔹 Step 4: Connect to Ethereum Network

# %%
infura_url = "https://sepolia.infura.io/v3/YOUR_PROJECT_ID"
w3 = Web3(Web3.HTTPProvider(infura_url))

print("Connected:", w3.is_connected())
# Out:
# Connected: False

# %% [markdown]
# ## 🔹 Step 5: Wallet Configuration

# %%
account = "YOUR_WALLET_ADDRESS"
private_key = "YOUR_PRIVATE_KEY"

# %% [markdown]
# ## 🔹 Step 6: Write Token Smart Contract

# %%
contract_source_code = '''
pragma solidity ^0.8.0;

contract SimpleToken {
    mapping(address => uint) public balances;
    uint public totalSupply;

    constructor(uint initialSupply) {
        balances[msg.sender] = initialSupply;
        totalSupply = initialSupply;
    }

    function transfer(address receiver, uint amount) public {
        require(balances[msg.sender] >= amount, "Insufficient Balance");

        balances[msg.sender] -= amount;
        balances[receiver] += amount;
    }

    function getBalance(address account) public view returns (uint) {
        return balances[account];
    }
}
'''

# %% [markdown]
# ## 🔹 Step 7: Compile Contract

# %%
compiled_sol = compile_source(contract_source_code)
contract_id, contract_interface = compiled_sol.popitem()

bytecode = contract_interface['bin']
abi = contract_interface['abi']

# %% [markdown]
# ## 🔹 Step 8: Deploy Contract

# %%
Token = w3.eth.contract(abi=abi, bytecode=bytecode)

nonce = w3.eth.get_transaction_count(account)

transaction = Token.constructor(1000).build_transaction({
    'from': account,
    'nonce': nonce,
    'gas': 2000000,
    'gasPrice': w3.to_wei('10', 'gwei')
})

signed_txn = w3.eth.account.sign_transaction(transaction, private_key)
tx_hash = w3.eth.send_raw_transaction(signed_txn.rawTransaction)

print("Deploying Token Contract... TX:", tx_hash.hex())
# Out:
# ---------------------------------------------------------------------------
# InvalidAddress                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 Token = w3.eth.contract(abi=abi, bytecode=bytecode)
# ----> 3 nonce = w3.eth.get_transaction_count(account)
#       5 transaction = Token.constructor(1000).build_transaction({
#       6     'from': account,
#       7     'nonce': nonce,
#       8     'gas': 2000000,
#       9     'gasPrice': w3.to_wei('10', 'gwei')
#      10 })
#      12 signed_txn = w3.eth.account.sign_transaction(transaction, private_key)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\eth\eth.py:485, in Eth.get_transaction_count(self, account, block_identifier)
#     480 def get_transaction_count(
#     481     self,
#     482     account: Union[Address, ChecksumAddress, ENS],
#     483     block_identifier: Optional[BlockIdentifier] = None,
#     484 ) -> Nonce:
# --> 485     return self._get_transaction_count(account, block_identifier)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\module.py:101, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#      99 def caller(*args: Any, **kwargs: Any) -> Union[TReturn, LogFilter]:
#     100     try:
# --> 101         (method_str, params), response_formatters = method.process_params(
#     102             module, *args, **kwargs
#     103         )
#     104     except _UseExistingFilter as err:
#     105         return LogFilter(eth_module=module, filter_id=err.filter_id)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\method.py:237, in Method.process_params(self, module, *args, **kwargs)
#     229 method = self.method_selector_fn()
#     230 response_formatters = (
#     231     self.result_formatters(method, module),
#     232     get_error_formatters(method),
#     233     self.null_result_formatters(method),
#     234 )
#     235 request = (
#     236     method,
# --> 237     _apply_request_formatters(params, self.request_formatters(method)),
#     238 )
#     239 return request, response_formatters
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\eth_utils\functional.py:49, in apply_to_return_value.<locals>.outer.<locals>.inner(*args, **kwargs)
#      47 @functools.wraps(fn)
#      48 def inner(*args, **kwargs) -> T:  # type: ignore
# ---> 49     return callback(fn(*args, **kwargs))
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\method.py:64, in _apply_request_formatters(params, request_formatters)
#      59 @to_tuple
#      60 def _apply_request_formatters(
#      61     params: Any, request_formatters: Dict[RPCEndpoint, Callable[..., TReturn]]
#      62 ) -> Tuple[Any, ...]:
#      63     if request_formatters:
# ---> 64         formatted_params = pipe(params, request_formatters)
#      65         return formatted_params
#      66     return params
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\cytoolz\functoolz.pyx:706, in cytoolz.functoolz.pipe()
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\cytoolz\functoolz.pyx:681, in cytoolz.functoolz.c_pipe()
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\cytoolz\functoolz.pyx:544, in cytoolz.functoolz.Compose.__call__()
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\cytoolz\functoolz.pyx:289, in cytoolz.functoolz.curry.__call__()
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\abi.py:613, in map_abi_data(normalizers, types, data)
#     585 @curry
#     586 def map_abi_data(
#     587     normalizers: Iterable[Callable[[TypeStr, Any], Tuple[TypeStr, Any]]],
#     588     types: Iterable[TypeStr],
#     589     data: Iterable[Any],
#     590 ) -> Any:
#     591     """
#     592     Applies normalizers to your data, in the context of the relevant types.
#     593     Each normalizer is in the format:
#    (...)
#     611     3. Stripping the types back out of the tree
#     612     """
# --> 613     return pipe(
#     614         data,
#     615         # 1. Decorating the data tree with types
#     616         abi_data_tree(types),
#     617         # 2. Recursively mapping each of the normalizers to the data
#     618         *map(data_tree_map, normalizers),
#     619         # 3. Stripping the types back out of the tree
#     620         strip_abi_types,
#     621     )
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\cytoolz\functoolz.pyx:706, in cytoolz.functoolz.pipe()
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\cytoolz\functoolz.pyx:681, in cytoolz.functoolz.c_pipe()
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\cytoolz\functoolz.pyx:289, in cytoolz.functoolz.curry.__call__()
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\abi.py:655, in data_tree_map(func, data_tree)
#     652     else:
#     653         return elements
# --> 655 return recursive_map(map_to_typed_data, data_tree)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\decorators.py:38, in reject_recursive_repeats.<locals>.wrapped(*args)
#      36 add_call(thread_local_args)
#      37 try:
# ---> 38     return to_wrap(*args)
#      39 finally:
#      40     remove_call(thread_local_args)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\formatters.py:89, in recursive_map(func, data)
#      86 def recurse(item: Any) -> TReturn:
#      87     return recursive_map(func, item)
# ---> 89 items_mapped = map_collection(recurse, data)
#      90 return func(items_mapped)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\formatters.py:73, in map_collection(func, collection)
#      71     return collection
#      72 elif isinstance(collection, Iterable):
# ---> 73     return datatype(map(func, collection))
#      74 else:
#      75     return collection
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\formatters.py:87, in recursive_map.<locals>.recurse(item)
#      86 def recurse(item: Any) -> TReturn:
# ---> 87     return recursive_map(func, item)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\decorators.py:38, in reject_recursive_repeats.<locals>.wrapped(*args)
#      36 add_call(thread_local_args)
#      37 try:
# ---> 38     return to_wrap(*args)
#      39 finally:
#      40     remove_call(thread_local_args)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\formatters.py:90, in recursive_map(func, data)
#      87     return recursive_map(func, item)
#      89 items_mapped = map_collection(recurse, data)
# ---> 90 return func(items_mapped)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\abi.py:651, in data_tree_map.<locals>.map_to_typed_data(elements)
#     649 def map_to_typed_data(elements: Any) -> "ABITypedData":
#     650     if isinstance(elements, ABITypedData) and elements.abi_type is not None:
# --> 651         return ABITypedData(func(*elements))
#     652     else:
#     653         return elements
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\normalizers.py:79, in implicitly_identity.<locals>.wrapper(type_str, data)
#      77 @functools.wraps(to_wrap)
#      78 def wrapper(type_str: TypeStr, data: Any) -> Tuple[TypeStr, Any]:
# ---> 79     modified = to_wrap(type_str, data)
#      80     if modified is None:
#      81         return type_str, data
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\normalizers.py:202, in abi_address_to_hex(type_str, data)
#     197 @implicitly_identity
#     198 def abi_address_to_hex(
#     199     type_str: TypeStr, data: Any
#     200 ) -> Optional[Tuple[TypeStr, ChecksumAddress]]:
#     201     if type_str == "address":
# --> 202         validate_address(data)
#     203         if is_binary_address(data):
#     204             return type_str, to_checksum_address(data)
#
# File h:\Labs\Blockchain Technology\.venv\lib\site-packages\web3\_utils\validation.py:184, in validate_address(value)
#     182 if is_not_address_string(value):
#     183     if not is_valid_ens_name(value):
# --> 184         raise InvalidAddress(f"ENS name: '{value}' is invalid.")
#     185     return
#     186 if is_bytes(value):
#
# InvalidAddress: ENS name: 'YOUR_WALLET_ADDRESS' is invalid.

# %% [markdown]
# ## 🔹 Step 9: Get Contract Address

# %%
tx_receipt = w3.eth.wait_for_transaction_receipt(tx_hash)
contract_address = tx_receipt.contractAddress

print("Contract Address:", contract_address)

# %% [markdown]
# ## 🔹 Step 10: Interact with Contract

# %%
contract = w3.eth.contract(address=contract_address, abi=abi)

# Check initial balance
balance = contract.functions.getBalance(account).call()
print("Owner Balance:", balance)

# %% [markdown]
# ## 🔹 Step 11: Transfer Tokens

# %%
receiver = "RECEIVER_ADDRESS"

nonce = w3.eth.get_transaction_count(account)

txn = contract.functions.transfer(receiver, 100).build_transaction({
    'from': account,
    'nonce': nonce,
    'gas': 200000,
    'gasPrice': w3.to_wei('10', 'gwei')
})

signed_txn = w3.eth.account.sign_transaction(txn, private_key)
tx_hash = w3.eth.send_raw_transaction(signed_txn.rawTransaction)

print("Transfer TX:", tx_hash.hex())

# %% [markdown]
# ## 🔹 Step 12: Check Updated Balances

# %%
owner_balance = contract.functions.getBalance(account).call()
receiver_balance = contract.functions.getBalance(receiver).call()

print("Owner Balance:", owner_balance)
print("Receiver Balance:", receiver_balance)

# %% [markdown]
# ## ✅ Expected Output
#
# Connected: True
# Deploying Token Contract... TX: 0x...
#
# Owner Balance: 1000
#
# Transfer TX: 0x...
#
# Owner Balance: 900
# Receiver Balance: 100
#
# ## 🧾 Result
# Token smart contract successfully deployed.
# Tokens transferred between accounts.
# Balances updated correctly.
#
# ## ⚠️ Precautions
# Ensure sufficient test ETH for gas.
# Always validate balance before transfer.
# Use test network only.
#
# ## 🔍 Conclusion
# This assignment demonstrates creation of a custom token system and secure transfer using smart contracts.
